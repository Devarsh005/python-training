# %% [markdown]
# # scope in  python

# %%
buitin_names = dir(__builtins__)
for name in buitin_names:
    print(name)
# Out:
# ArithmeticError
# AssertionError
# AttributeError
# BaseException
# BaseExceptionGroup
# BlockingIOError
# BrokenPipeError
# BufferError
# BytesWarning
# ChildProcessError
# ConnectionAbortedError
# ConnectionError
# ConnectionRefusedError
# ConnectionResetError
# DeprecationWarning
# EOFError
# Ellipsis
# EncodingWarning
# EnvironmentError
# Exception
# ExceptionGroup
# False
# FileExistsError
# FileNotFoundError
# FloatingPointError
# FutureWarning
# GeneratorExit
# IOError
# ImportError
# ImportWarning
# IndentationError
# IndexError
# InterruptedError
# IsADirectoryError
# KeyError
# KeyboardInterrupt
# LookupError
# MemoryError
# ModuleNotFoundError
# NameError
# None
# NotADirectoryError
# NotImplemented
# NotImplementedError
# OSError
# OverflowError
# PendingDeprecationWarning
# PermissionError
# ProcessLookupError
# RecursionError
# ReferenceError
# ResourceWarning
# RuntimeError
# RuntimeWarning
# StopAsyncIteration
# StopIteration
# SyntaxError
# SyntaxWarning
# ...

# %%
# local scope best example
def local_scope_demo():
    local_variable = 10
    print(local_variable)

local_scope_demo()
print(local_variable) 
# because of it is not defined outside the function
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       4     print(local_variable)
#       6 local_scope_demo()
# ----> 7 print(local_variable)
#
# NameError: name 'local_variable' is not defined
